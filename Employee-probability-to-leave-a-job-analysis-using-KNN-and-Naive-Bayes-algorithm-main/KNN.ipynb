# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2936 sha256=8701d92e05ae8649be744f711dfead25b70f304a210b75c1eb8b108f0d58c0cb
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\db\9f\0b\772886b624f84c138a5febb6966c89d374ab58c62bd65d109e
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import tree

from sklearn.neighbors import KNeighborsClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       2 import pandas as pd
#       3 from pandas import DataFrame
# ----> 4 from sklearn.model_selection import train_test_split
#       5 from sklearn import preprocessing
#       6 from sklearn import tree
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
dataset = pd.read_csv(r"C:\Users\ADMIN\Desktop\IMAGE CLASSIFICATION USING CNN KERAS\New folder\Employee-probability-to-leave-a-job-analysis-using-KNN-and-Naive-Bayes-algorithm-main\dataset.csv")

# %%
dataset.head()
# Out:
#   Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0       Yes       1102                 1          2              1
# 1        No        279                 8          1              1
# 2       Yes       1373                 2          2              1
# 3        No       1392                 3          4              1
# 4        No        591                 2          1              1
#
#    EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0               1                        2          94               3
# 1               2                        3          61               2
# 2               4                        4          92               2
# 3               5                        4          56               3
# 4               7                        1          40               3
#
#    JobLevel  ...  PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0         2  ...                  3                         1             80
# 1         2  ...                  4                         4             80
# 2         1  ...                  3                         2             80
# 3         1  ...                  3                         3             80
# 4         1  ...                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion
# 0                        0
# 1                        1
# 2                        0
# 3                        3
# 4                        2
#
# [5 rows x 26 columns]

# %%
feature=dataset.columns

# %%
feature
# Out:
# Index(['Attrition', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'YearsWithCurrManager', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion'],
#       dtype='object')

# %%
feature=[x for x in feature if x !='Attrition']

# %%
feature
# Out:
# ['DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'YearsWithCurrManager',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion']

# %%
conda install -c conda-forge scikit-learn
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\ADMIN\anaconda3\envs\TENSORFLOW
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     joblib-1.2.0               |     pyhd8ed1ab_0         205 KB  conda-forge
#     libblas-3.9.0              |1_h8933c1f_netlib         193 KB  conda-forge
#     libcblas-3.9.0             |5_hd5c7e75_netlib          95 KB  conda-forge
#     m2w64-gcc-libgfortran-5.3.0|                6         342 KB  conda-forge
#     m2w64-gcc-libs-5.3.0       |                7         520 KB  conda-forge
#     m2w64-gcc-libs-core-5.3.0  |                7         214 KB  conda-forge
#     m2w64-gmp-6.1.0            |                2         726 KB  conda-forge
#     m2w64-libwinpthread-git-5.0.0.4634.697f757|                2          31 KB  conda-forge
#     msys2-conda-epoch-20160418 |                1           3 KB  conda-forge
#     python_abi-3.10            |          2_cp310           4 KB  conda-forge
#     scikit-learn-1.1.2         |  py310h3a564e9_0         7.5 MB  conda-forge
#     threadpoolctl-3.1.0        |     pyh8a188c0_0          18 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         9.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             conda-forge/noarch::joblib-1.2.0-pyhd8ed1ab_0 None
#   libblas            conda-forge/win-64::libblas-3.9.0-1_h8933c1f_netlib None
#   libcblas           conda-forge/win-64::libcblas-3.9.0-5_hd5c7e75_netlib None
#   m2w64-gcc-libgfor~ conda-forge/win-64::m2w64-gcc-libgfortran-5.3.0-6 None
#   m2w64-gcc-libs     conda-forge/win-64::m2w64-gcc-libs-5.3.0-7 None
#   m2w64-gcc-libs-co~ conda-forge/win-64::m2w64-gcc-libs-core-5.3.0-7 None
#   m2w64-gmp          conda-forge/win-64::m2w64-gmp-6.1.0-2 None
#   m2w64-libwinpthre~ conda-forge/win-64::m2w64-libwinpthread-git-5.0.0.4634.697f757-2 None
#   msys2-conda-epoch  conda-forge/win-64::msys2-conda-epoch-20160418-1 None
#   python_abi         conda-forge/win-64::python_abi-3.10-2_cp310 None
#   scikit-learn       conda-forge/win-64::scikit-learn-1.1.2-py310h3a564e9_0 None
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.1.0-pyh8a188c0_0 None
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.10.11~ --> conda-forge::ca-certificates-2022.12.7-h5b45459_0 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/win-64::certifi-2022.12.7-p~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0 None
#
#
#
# Downloading and Extracting Packages
#
# m2w64-gmp-6.1.0      | 726 KB    |            |   0%
# m2w64-gmp-6.1.0      | 726 KB    | 2          |   2%
# m2w64-gmp-6.1.0      | 726 KB    | #3         |  13%
# m2w64-gmp-6.1.0      | 726 KB    | ##2        |  22%
# m2w64-gmp-6.1.0      | 726 KB    | ####6      |  46%
# m2w64-gmp-6.1.0      | 726 KB    | #####7     |  57%
# m2w64-gmp-6.1.0      | 726 KB    | #######    |  71%
# m2w64-gmp-6.1.0      | 726 KB    | ########1  |  82%
# m2w64-gmp-6.1.0      | 726 KB    | #########4 |  95%
# m2w64-gmp-6.1.0      | 726 KB    | ########## | 100%
#
# joblib-1.2.0         | 205 KB    |            |   0%
# joblib-1.2.0         | 205 KB    | 7          |   8%
# joblib-1.2.0         | 205 KB    | ####6      |  47%
# joblib-1.2.0         | 205 KB    | ########## | 100%
# joblib-1.2.0         | 205 KB    | ########## | 100%
#
# libcblas-3.9.0       | 95 KB     |            |   0%
# libcblas-3.9.0       | 95 KB     | #6         |  17%
# libcblas-3.9.0       | 95 KB     | ########## | 100%
# libcblas-3.9.0       | 95 KB     | ########## | 100%
#
# m2w64-gcc-libgfortra | 342 KB    |            |   0%
# m2w64-gcc-libgfortra | 342 KB    | 4          |   5%
# m2w64-gcc-libgfortra | 342 KB    | ###2       |  33%
# m2w64-gcc-libgfortra | 342 KB    | ######     |  61%
# m2w64-gcc-libgfortra | 342 KB    | ########4  |  84%
# m2w64-gcc-libgfortra | 342 KB    | ########## | 100%
#
# msys2-conda-epoch-20 | 3 KB      |            |   0%
# msys2-conda-epoch-20 | 3 KB      | ########## | 100%
# msys2-conda-epoch-20 | 3 KB      | ########## | 100%
#
# python_abi-3.10      | 4 KB      |            |   0%
# python_abi-3.10      | 4 KB      | ########## | 100%
# python_abi-3.10      | 4 KB      | ########## | 100%
#
# m2w64-gcc-libs-5.3.0 | 520 KB    |            |   0%
# m2w64-gcc-libs-5.3.0 | 520 KB    | 3          |   3%
# m2w64-gcc-libs-5.3.0 | 520 KB    | ###        |  31%
# m2w64-gcc-libs-5.3.0 | 520 KB    | ####9      |  49%
# m2w64-gcc-libs-5.3.0 | 520 KB    | ######4    |  65%
# m2w64-gcc-libs-5.3.0 | 520 KB    | ########   |  80%
# m2w64-gcc-libs-5.3.0 | 520 KB    | #########8 |  98%
# m2w64-gcc-libs-5.3.0 | 520 KB    | ########## | 100%
#
# libblas-3.9.0        | 193 KB    |            |   0%
# libblas-3.9.0        | 193 KB    | 8          |   8%
# libblas-3.9.0        | 193 KB    | ########## | 100%
#
# m2w64-gcc-libs-core- | 214 KB    |            |   0%
# m2w64-gcc-libs-core- | 214 KB    | 7          |   7%
# m2w64-gcc-libs-core- | 214 KB    | ######7    |  67%
# m2w64-gcc-libs-core- | 214 KB    | ########## | 100%
#
# threadpoolctl-3.1.0  | 18 KB     |            |   0%
# threadpoolctl-3.1.0  | 18 KB     | ########9  |  90%
# threadpoolctl-3.1.0  | 18 KB     | ########## | 100%
#
# m2w64-libwinpthread- | 31 KB     |            |   0%
# m2w64-libwinpthread- | 31 KB     | #####1     |  51%
# m2w64-libwinpthread- | 31 KB     | ########## | 100%
#
# scikit-learn-1.1.2   | 7.5 MB    |            |   0%
# scikit-learn-1.1.2   | 7.5 MB    |            |   0%
# scikit-learn-1.1.2   | 7.5 MB    |            |   1%
# scikit-learn-1.1.2   | 7.5 MB    | 2          |   2%
# scikit-learn-1.1.2   | 7.5 MB    | 3          |   4%
# scikit-learn-1.1.2   | 7.5 MB    | 4          |   4%
# scikit-learn-1.1.2   | 7.5 MB    | 5          |   5%
# scikit-learn-1.1.2   | 7.5 MB    | 6          |   6%
# scikit-learn-1.1.2   | 7.5 MB    | 7          |   7%
# scikit-learn-1.1.2   | 7.5 MB    | 8          |   8%
# scikit-learn-1.1.2   | 7.5 MB    | 9          |   9%
# scikit-learn-1.1.2   | 7.5 MB    | #          |  10%
# scikit-learn-1.1.2   | 7.5 MB    | #1         |  11%
# scikit-learn-1.1.2   | 7.5 MB    | #2         |  13%
# scikit-learn-1.1.2   | 7.5 MB    | #3         |  14%
# scikit-learn-1.1.2   | 7.5 MB    | #4         |  15%
# scikit-learn-1.1.2   | 7.5 MB    | #5         |  16%
# scikit-learn-1.1.2   | 7.5 MB    | #7         |  17%
# scikit-learn-1.1.2   | 7.5 MB    | #8         |  19%
# scikit-learn-1.1.2   | 7.5 MB    | ##         |  20%
# scikit-learn-1.1.2   | 7.5 MB    | ##1        |  21%
# scikit-learn-1.1.2   | 7.5 MB    | ##2        |  23%
# scikit-learn-1.1.2   | 7.5 MB    | ##3        |  24%
# scikit-learn-1.1.2   | 7.5 MB    | ##4        |  25%
# scikit-learn-1.1.2   | 7.5 MB    | ##5        |  26%
# scikit-learn-1.1.2   | 7.5 MB    | ##6        |  27%
# scikit-learn-1.1.2   | 7.5 MB    | ##8        |  28%
# scikit-learn-1.1.2   | 7.5 MB    | ##9        |  29%
# scikit-learn-1.1.2   | 7.5 MB    | ###        |  30%
# scikit-learn-1.1.2   | 7.5 MB    | ###2       |  33%
# scikit-learn-1.1.2   | 7.5 MB    | ###3       |  34%
# scikit-learn-1.1.2   | 7.5 MB    | ###5       |  35%
# scikit-learn-1.1.2   | 7.5 MB    | ###6       |  36%
# scikit-learn-1.1.2   | 7.5 MB    | ###7       |  38%
# scikit-learn-1.1.2   | 7.5 MB    | ###8       |  39%
# scikit-learn-1.1.2   | 7.5 MB    | ####       |  40%
# scikit-learn-1.1.2   | 7.5 MB    | ####1      |  41%
# scikit-learn-1.1.2   | 7.5 MB    | ####2      |  43%
# scikit-learn-1.1.2   | 7.5 MB    | ####3      |  44%
# scikit-learn-1.1.2   | 7.5 MB    | ####5      |  45%
# scikit-learn-1.1.2   | 7.5 MB    | ####6      |  46%
# scikit-learn-1.1.2   | 7.5 MB    | ####7      |  47%
# scikit-learn-1.1.2   | 7.5 MB    | ####8      |  48%
# scikit-learn-1.1.2   | 7.5 MB    | ####9      |  49%
# scikit-learn-1.1.2   | 7.5 MB    | #####      |  50%
# scikit-learn-1.1.2   | 7.5 MB    | #####1     |  51%
# scikit-learn-1.1.2   | 7.5 MB    | #####2     |  53%
# scikit-learn-1.1.2   | 7.5 MB    | #####3     |  54%
# scikit-learn-1.1.2   | 7.5 MB    | #####4     |  55%
# scikit-learn-1.1.2   | 7.5 MB    | #####5     |  56%
# scikit-learn-1.1.2   | 7.5 MB    | #####6     |  57%
# scikit-learn-1.1.2   | 7.5 MB    | #####7     |  58%
# scikit-learn-1.1.2   | 7.5 MB    | #####9     |  60%
# scikit-learn-1.1.2   | 7.5 MB    | ######     |  61%
# scikit-learn-1.1.2   | 7.5 MB    | ######2    |  62%
# scikit-learn-1.1.2   | 7.5 MB    | ######3    |  63%
# scikit-learn-1.1.2   | 7.5 MB    | ######4    |  64%
# scikit-learn-1.1.2   | 7.5 MB    | ######5    |  65%
# scikit-learn-1.1.2   | 7.5 MB    | ######6    |  67%
# scikit-learn-1.1.2   | 7.5 MB    | ######8    |  69%
# scikit-learn-1.1.2   | 7.5 MB    | #######    |  70%
# scikit-learn-1.1.2   | 7.5 MB    | #######1   |  71%
# scikit-learn-1.1.2   | 7.5 MB    | #######3   |  74%
# scikit-learn-1.1.2   | 7.5 MB    | #######5   |  75%
# scikit-learn-1.1.2   | 7.5 MB    | #######6   |  77%
# scikit-learn-1.1.2   | 7.5 MB    | #######7   |  78%
# scikit-learn-1.1.2   | 7.5 MB    | #######9   |  79%
# scikit-learn-1.1.2   | 7.5 MB    | ########   |  80%
# scikit-learn-1.1.2   | 7.5 MB    | ########1  |  81%
# scikit-learn-1.1.2   | 7.5 MB    | ########2  |  82%
# scikit-learn-1.1.2   | 7.5 MB    | ########4  |  84%
# scikit-learn-1.1.2   | 7.5 MB    | ########6  |  86%
# scikit-learn-1.1.2   | 7.5 MB    | #########  |  90%
# scikit-learn-1.1.2   | 7.5 MB    | #########1 |  91%
# scikit-learn-1.1.2   | 7.5 MB    | #########2 |  92%
# scikit-learn-1.1.2   | 7.5 MB    | #########3 |  94%
# scikit-learn-1.1.2   | 7.5 MB    | #########4 |  95%
# scikit-learn-1.1.2   | 7.5 MB    | #########5 |  96%
# scikit-learn-1.1.2   | 7.5 MB    | #########7 |  98%
# scikit-learn-1.1.2   | 7.5 MB    | #########9 |  99%
# scikit-learn-1.1.2   | 7.5 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
from sklearn.model_selection import train_test_split


train, test = train_test_split(dataset, test_size = 0.08)

# %%
print(len(dataset))
print(len(train))
print(len(test))
# Out:
# 1470
# 1352
# 118

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
KN = KNeighborsClassifier(n_neighbors=3)

# %%
x_train = train[feature]
y_train = train["Attrition"]
    
x_test = test[feature]
y_test = test["Attrition"]

# %%
KNN = KN.fit(x_train, y_train)

# %%
y_pred = KNN.predict(x_test)

# %%
y_pred
# Out:
# array(['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test, y_pred) * 100
print("Accuracy using KNeighborsClassifier: ", round(score, 1),"%")
# Out:
# Accuracy using KNeighborsClassifier:  78.8 %
